# %% [markdown]
# <a href="https://colab.research.google.com/github/yogeshsinghgit/MLProject1/blob/main/Employee_Attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Employee Attrition.ipynb Machine Learning Project

# %% [markdown]
# ### About Dataset
#
# [DataSet Link](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset)
#
# [Problem Statement and features Explanation](https://inseaddataanalytics.github.io/INSEADAnalytics/groupprojects/January2018FBL/IBM_Attrition_VSS.html)
#
# Uncover the factors that lead to employee attrition *( Employee attrition is the natural process of leaving the workforce due to personal or professional reasons.)* and explore important questions such as ‘show me a breakdown of distance from home by job role and attrition’ or ‘compare average monthly income by education and attrition’. This is a fictional data set created by IBM data scientists.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

import warnings
warnings.filterwarnings('ignore')

# %%
FILE_PATH = "/content/Attrition.csv"

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv(FILE_PATH)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ## Basic EDA

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
# df.columns

# %% [markdown]
# ### Target Variable

# %%
print(df['Attrition'].value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
# sns.countplot(x='Attrition', data = df)
# plt.show()

# %%
df['Attrition'].value_counts().plot(kind='pie', autopct="%0.2f", title='Attrition Count')
plt.show()

# %% [markdown]
# #### Conclusion:
#
# Dataset is imbalance because there is a big number of target variable imbalance.
#
#
# Yes: 237
#
# No:  1233
#
# Total: 1470

# %% [markdown]
# ### Target Varibale Vs Other features EDA

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
# print(df['JobRole'].unique())

print(df['JobRole'].value_counts())
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 12))
sns.countplot(x ='JobRole', data = df, hue='Attrition')
plt.title('Attrition w.r.t Job Role')
plt.show()

# %%
df.groupby("Attrition")["JobRole"].value_counts()
# Out:
# Attrition  JobRole
# No         Sales Executive              269
#            Research Scientist           245
#            Laboratory Technician        197
#            Manufacturing Director       135
#            Healthcare Representative    122
#            Manager                       97
#            Research Director             78
#            Sales Representative          50
#            Human Resources               40
# Yes        Laboratory Technician         62
#            Sales Executive               57
#            Research Scientist            47
#            Sales Representative          33
#            Human Resources               12
#            Manufacturing Director        10
#            Healthcare Representative      9
#            Manager                        5
#            Research Director              2
# Name: count, dtype: int64

# %%
df.groupby("Attrition")["Department"].value_counts()
# Out:
# Attrition  Department
# No         Research & Development    828
#            Sales                     354
#            Human Resources            51
# Yes        Research & Development    133
#            Sales                      92
#            Human Resources            12
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
sns.countplot(x ='Department', data = df, hue='Attrition')
plt.title('Attrition w.r.t Job Role')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.countplot(x ='EducationField', data = df, hue='Attrition')
plt.title('Attrition w.r.t Education Field')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x ='Gender', data = df, hue='Attrition')
plt.title('Attrition w.r.t Gender')
plt.xticks(rotation=45)
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
# df['count']=1

# %%
# df.groupby(["Gender", "Attrition"]).agg({'count':'sum'})
# Out:
#                   count
# Gender Attrition
# Female No           501
#        Yes           87
# Male   No           732
#        Yes          150

# %%
df.groupby("Gender")["Attrition"].value_counts()
# Out:
# Gender  Attrition
# Female  No           501
#         Yes           87
# Male    No           732
#         Yes          150
# Name: count, dtype: int64

# %%
# sns.pairplot(df)

# %%
sns.pairplot(df, y='Attrition')

# %% [markdown]
# ## creating pipeline to scale values.

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %% [markdown]
# We only has numerical features in dataset so we are creating a single piepline.

# %%
feature_pipeline = Pipeline(
    steps = [
        ('imputer', SimpleImputer(strategy= 'median')), # handling missing values
        ('scaler', StandardScaler() ) # feature scaling
    ])

# %%
feature_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler())])

# %%
X = feature_pipeline.fit_transform(X)

# %% [markdown]
# ## Train Test Split dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2 ,random_state= 45)

# %% [markdown]
# ## Model Training
#
# Models Used:
#
# * Linear Regression
# * Ridge Regression
# * Lasso Regression
# * Elastic Net
# * Decision Tree Regressor.

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
models = {
    'Random Forest Regressor': RandomForestRegressor(),
    'Decision Tree Regressor': DecisionTreeRegressor(),
    'Linear Regressior': LinearRegression(),
    'Ridge Regressor': Ridge(),
    'Lasso Regressor': Lasso(),
    'Elastic Net': ElasticNet()
}

# %% [markdown]
# ## Evaluate between models

# %%
def evaluate_model(X_train,y_train,X_test,y_test,models):

    report = {}
    for i in range(len(models)):
        model = list(models.values())[i]
        # Train model
        model.fit(X_train,y_train)

        # Predict Testing data
        y_test_pred =model.predict(X_test)

        # Get accuracy for test data prediction

        test_model_score = r2_score(y_test,y_test_pred)

        report[list(models.keys())[i]] =  test_model_score



    return report

# %%
evaluate_model(X_train,y_train,X_test,y_test,models)
# Out:
# {'Random Forest Regressor': 0.5175052625334833,
#  'Decision Tree Regressor': -0.1264443307966825,
#  'Linear Regressior': 0.575715140543105,
#  'Ridge Regressor': 0.5758041396635609,
#  'Lasso Regressor': 0.5468434705356993,
#  'Elastic Net': 0.48378510728648494}

# %% [markdown]
# Selecting Linear Regression

# %% [markdown]
# ## Hyparameter Tuning Linear Regression

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Define the hyperparameter grid for Linear Regression
param_grid = {
    'fit_intercept': [True, False],  # Whether to fit the intercept term
}

# %%
# Create the Linear Regression model
linear_reg = LinearRegression()

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=linear_reg,
                           param_grid=param_grid,
                           cv=5,
                           scoring='neg_mean_squared_error')  # Use negative MSE for minimization

# Fit the grid search to the training data
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False]},
#              scoring='neg_mean_squared_error')

# %%
# Get the best model and its parameters
best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

# Make predictions on the test set using the best model
y_pred = best_model.predict(X_test)

# Evaluate the model's performance on the test set (e.g., calculate MSE)
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

# Print results
print("Best Model Parameters:", best_params)
print("Mean Squared Error:", mse)
print("R2 Score:", r2)
# Out:
# Best Model Parameters: {'fit_intercept': True}
# Mean Squared Error: 100.01373326017566
# R2 Score: 0.575715140543105

# %%
# Visualization: Actual vs. Predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted House Prices')
plt.show()

# %% [markdown]
# # Final Thoughts

# %% [markdown]
# The pyhton code shows how can you create a piepline to transform data, how to comapare between different models and how to hyparameter tune them as well.
#
# Although we doesn't get a model with 80-90% accuracy but atleast we tried each and every regression model.
#
# to get better accuracy we can try deep learning model, maybe it will help with higher accuracy than machine learning algorithms.
